# %%
import json

# %%
data = {
    "img_name": ["GOPRO-20250325-011208-000016.jpg"],
    "car": [
        {
            "x_min": 0.36403142288327217,
            "y_min": 0.5174379870295525,
            "x_max": 0.43284357711672783,
            "y_max": 0.5743588879704475
        },
        {
            "x_min": 0.19938648492097855,
            "y_min": 0.5249275788664818,
            "x_max": 0.26545726507902145,
            "y_max": 0.6332755461335182
        },
        {
            "x_min": 0.12199965491890907,
            "y_min": 0.528762474656105,
            "x_max": 0.20026597008109093,
            "y_max": 0.631393775343895
        },
        {
            "x_min": 0.07496892288327217,
            "y_min": 0.5305647179484367,
            "x_max": 0.14378107711672783,
            "y_max": 0.6042009070515633
        },
        {
            "x_min": 0.05356748588383198,
            "y_min": 0.5231657847762108,
            "x_max": 0.09877626411616802,
            "y_max": 0.5725373402237892
        },
        {
            "x_min": 0.03974943980574608,
            "y_min": 0.517803929746151,
            "x_max": 0.07353181019425392,
            "y_max": 0.558367945253849
        },
        {
            "x_min": 0.030174563638865948,
            "y_min": 0.5114453183487058,
            "x_max": 0.05576293636113405,
            "y_max": 0.5373828066512942
        },
        {
            "x_min": 0.027430727146565914,
            "y_min": 0.509199888445437,
            "x_max": 0.048741147853434086,
            "y_max": 0.533768861554563
        }
    ],
    "pothole": [
        {
            "x_min": 0.3683171395678073,
            "y_min": 0.5288466406054795,
            "x_max": 0.3758234854321927,
            "y_max": 0.5375596093945205
        }
    ],
    "street light and pole": [
        {
            "x_min": 0.40033760108053684,
            "y_min": 0.299577459692955,
            "x_max": 0.43169364891946316,
            "y_max": 0.512922540307045
        },
        {
            "x_min": 0.023512196727097034,
            "y_min": 0.43043767288327217,
            "x_max": 0.042894053272902966,
            "y_max": 0.49924982711672783
        }
    ]
}

# %%
for name in data: 
    if name == "img_name":
        print(data["img_name"][0])
        print(str(data["img_name"]))
# Out:
# GOPRO-20250325-011208-000016.jpg
# ['GOPRO-20250325-011208-000016.jpg']

# %%
for obj_nam in data:
    # print(obj_nam)
    for obj in data[obj_nam]:
        print(f"{obj_nam} {obj}")
# Out:
# img_name GOPRO-20250325-011208-000016.jpg
# car {'x_min': 0.36403142288327217, 'y_min': 0.5174379870295525, 'x_max': 0.43284357711672783, 'y_max': 0.5743588879704475}
# car {'x_min': 0.19938648492097855, 'y_min': 0.5249275788664818, 'x_max': 0.26545726507902145, 'y_max': 0.6332755461335182}
# car {'x_min': 0.12199965491890907, 'y_min': 0.528762474656105, 'x_max': 0.20026597008109093, 'y_max': 0.631393775343895}
# car {'x_min': 0.07496892288327217, 'y_min': 0.5305647179484367, 'x_max': 0.14378107711672783, 'y_max': 0.6042009070515633}
# car {'x_min': 0.05356748588383198, 'y_min': 0.5231657847762108, 'x_max': 0.09877626411616802, 'y_max': 0.5725373402237892}
# car {'x_min': 0.03974943980574608, 'y_min': 0.517803929746151, 'x_max': 0.07353181019425392, 'y_max': 0.558367945253849}
# car {'x_min': 0.030174563638865948, 'y_min': 0.5114453183487058, 'x_max': 0.05576293636113405, 'y_max': 0.5373828066512942}
# ...

# %%
out =  {'img_name': 'GOPRO-20250325-011208-000006.jpg', 'car': [{'x_min': 0.4422393199056387, 'y_min': 0.4994843937456608, 'x_max': 0.4796356800943613, 'y_max': 0.5434843562543392}, {'x_min': 0.7704027928411961, 'y_min': 0.5153532847762108, 'x_max': 0.8194409571588039, 'y_max': 0.5647248402237892}, {'x_min': 0.6248598620295525, 'y_min': 0.4994540400803089, 'x_max': 0.6817807629704475, 'y_max': 0.5591397099196911}, {'x_min': -0.0009765625, 'y_min': 0.6714911013841629, 'x_max': 0.9990234375, 'y_max': 0.9984307736158371}]}

# %%
let the "detectoin" to be in "model_output_json" and then i want to call "model_output_json" to extract the "img_name" and the class with its values [x_min, x_max, y_min, y_max] and that information to be used for the plutting on the image, so make sure that read the "img_name" then call the imag and then plut all classes in the same image. so the out put expected is image annotated and the json file
